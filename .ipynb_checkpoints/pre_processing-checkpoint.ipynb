# %%
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt
# %matplotlib inline
import matplotlib 
import seaborn as sns
matplotlib.rcParams["figure.figsize"] = (20,10)
import re

# %%
# Load the data
df = pd.read_csv('../data/cleaned_data.csv')

# Basic exploration
print(df.head())  # View first few rows
print(df.info())  # Data types and non-null counts
print(df.describe())  # Summary statistics for numerical features

# Check for missing values
print(df.isnull().sum())

# Visualize distributions
sns.histplot(df['Price'], kde=True)
plt.title('Price Distribution')
plt.show()

# Correlation heatmap for numerical features
numerical_cols = ['Latitude', 'Longitude', 'Rooms', 'Bathrooms', 'Car Parks', 'Size', 'Storeys']
corr = df[numerical_cols + ['Price']].corr()
sns.heatmap(corr, annot=True, cmap='coolwarm')
plt.title('Correlation Heatmap')
plt.show()

# Boxplots for categorical vs. Price
categorical_cols = ['Location', 'Type', 'Furnishing', 'Position']
for col in categorical_cols:
    sns.boxplot(x=col, y='Price', data=df)
    plt.title(f'{col} vs. Price')
    plt.xticks(rotation=45)
    plt.show()
# Out:
#               Location  Latitude   Longitude                Type  Rooms  \
# 0                 KLCC  3.159247  101.713366  Serviced Residence      3
# 1    Damansara Heights  3.152395  101.658445            Bungalow      6
# 2              Dutamas  3.032282  101.759884         Condominium      3
# 3          Bukit Jalil  3.053346  101.680294         Condominium      5
# 4  Taman Tun Dr Ismail  3.136141  101.630737            Bungalow      6
#
#    Bathrooms  Car Parks  Size        Furnishing  Storeys Position    Price
# 0          3          2  1335   Fully Furnished        1  Unknown  1250000
# 1          7          2  6900  Partly Furnished        1  Unknown  6800000
# 2          4          2  1875  Partly Furnished        1   Corner  1030000
# 3          3          2  1513  Partly Furnished        1   Corner   900000
# 4          5          4  7200  Partly Furnished        1  Unknown  5350000
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 42077 entries, 0 to 42076
# Data columns (total 12 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Location    42077 non-null  object
#  1   Latitude    42077 non-null  float64
#  2   Longitude   42077 non-null  float64
#  3   Type        42077 non-null  object
#  4   Rooms       42077 non-null  int64
#  5   Bathrooms   42077 non-null  int64
#  6   Car Parks   42077 non-null  int64
#  7   Size        42077 non-null  int64
#  8   Furnishing  42077 non-null  object
#  9   Storeys     42077 non-null  int64
#  10  Position    42077 non-null  object
#  11  Price       42077 non-null  int64
# dtypes: float64(2), int64(6), object(4)
# memory usage: 3.9+ MB
# None
#            Latitude     Longitude         Rooms     Bathrooms     Car Parks  \
# count  42077.000000  42077.000000  42077.000000  42077.000000  42077.000000
# mean       3.140667    101.687572      3.680823      3.065428      1.977541
# std        0.049375      0.036825      1.406660      1.538791      0.955814
# min        3.032282    101.575019      1.000000      1.000000      1.000000
# 25%        3.099192    101.658445      3.000000      2.000000      1.000000
# 50%        3.159247    101.681420      4.000000      3.000000      2.000000
# 75%        3.173433    101.713366      4.000000      4.000000      2.000000
# max        3.318904    101.768488     18.000000     20.000000     30.000000
#
#                Size       Storeys         Price
# count  42077.000000  42077.000000  4.207700e+04
# mean    1984.806807      1.183640  1.610119e+06
# std     1584.470710      0.501495  1.771134e+06
# min      400.000000      1.000000  1.050000e+05
# 25%     1025.000000      1.000000  6.000000e+05
# 50%     1422.000000      1.000000  9.988000e+05
# 75%     2208.000000      1.000000  1.890000e+06
# max    10000.000000      4.000000  5.000000e+07
# Location      0
# Latitude      0
# Longitude     0
# Type          0
# Rooms         0
# Bathrooms     0
# Car Parks     0
# Size          0
# Furnishing    0
# Storeys       0
# Position      0
# Price         0
# dtype: int64
